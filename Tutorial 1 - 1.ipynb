# %%
# 필요한 라이브러리를 미리 불러옵니다

# 텐서보드를 Colab 에서 실행하기 위한 라이브러리
# !wget -nc https://raw.githubusercontent.com/mixuala/colab_utils/master/tboard.py
import tboard
tboard.install_ngrok(bin_dir="./")

# MNIST 숫자 데이터를 다운로드 받는 라이브러리
from tensorflow.examples.tutorials.mnist.input_data import read_data_sets as load_mnist
load_mnist("MNIST_data/", one_hot=False)

# 그 외 필수 라이브러리
import tensorflow as tf
import numpy as np

# %%
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/A01E.mat
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/A01TClass1.mat
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/A01TClass2.mat
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/A01TClass3.mat
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/A01TClass4.mat
# !wget -nc -q https://github.com/wltjr1007/wltjr1007.github.io/raw/master/KHBM_ADNI_eMCINC_ERES.mat
from glob import glob
print(glob("*"))
# Out:
# wget: illegal option -- `-nq'
# Usage: wget [OPTION]... [URL]...
#
# Try `wget --help' for more options.
# ['datalab', 'A01TClass1.mat', 'A01E.mat', 'A01TClass4.mat', 'A01TClass2.mat', 'A01TClass3.mat', 'KHBM_ADNI_eMCINC_ERES.mat']
